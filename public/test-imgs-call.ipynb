# %% [markdown]
# ## Ditaa

# %% [markdown]
# [DIagrams Through Ascii Art](http://ditaa.sourceforge.net/) :
#
# ![img](img/ditaa-example-file.png)

# %% [markdown]
# ## Graphviz

# %% [markdown]
# The [reference for graph diagrams](https://www.graphviz.org/) :
#
# ![img](img/dot-example-file.svg)
#
# <div class="NOTES" id="org84f3d59">
# <p>
# Export to PNG or SVG.
# </p>
#
# </div>

# %% [markdown]
# ## Plantuml

# %% [markdown]
# [PlantUML](http://plantuml.com/) for most UML diagrams

# %% [markdown]
# ### Sequence diagrams

# %% [markdown]
# ![img](img/plantuml-seq-diag-example-file.png)

# %% [markdown]
# ### Use case diagrams

# %% [markdown]
# ![img](img/plantuml-use-case-diag-example-file.png)

# %% [markdown]
# ### Class diagrams

# %% [markdown]
# ![img](img/plantuml-class-diag-example-file.png)

# %% [markdown]
# ### Activity diagrams

# %% [markdown]
# ![img](img/plantuml-activity-diag-example-file.png)

# %% [markdown]
# ### State diagrams

# %% [markdown]
# ![img](img/plantuml-state-diag-example-file.png)
