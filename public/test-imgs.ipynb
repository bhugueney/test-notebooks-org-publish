# %% [markdown]
# ## Graphviz

# %% [markdown]
# The [reference for graph diagrams](https://www.graphviz.org/) :

# %%
digraph structs {
	node[shape=record]
	struct1 [label="<f0> left|<f1> mid\ dle|<f2> right"];
	struct2 [label="{<f0> one|<f1> two\n\n\n}" shape=Mrecord];
	struct3 [label="hello\nworld |{ b |{c|<here> d|e}| f}| g | h"];
	struct1:f1 -> struct2:f0;
	struct1:f0 -> struct3:f1;
}

# %% [markdown]
# <div class="NOTES">
# Export to PNG or SVG.
#
# </div>

# %% [markdown]
# ## Plantuml

# %% [markdown]
# [PlantUML](http://plantuml.com/) for most UML diagrams

# %% [markdown]
# ### Sequence diagrams

# %% [markdown]
# ![img](img/plantuml-seq-diag-example.png)

# %% [markdown]
# ### Use case diagrams

# %% [markdown]
# ![img](img/plantuml-use-case-diag-example.png)

# %% [markdown]
# ### Class diagrams

# %% [markdown]
# ![img](img/plantuml-class-diag-example.png)

# %% [markdown]
# ### Activity diagrams

# %% [markdown]
# ![img](img/plantuml-activity-diag-example.png)

# %% [markdown]
# ### State diagrams

# %% [markdown]
# ![img](img/plantuml-state-diag-example.png)
