# %% [markdown]
# ## test

# %% [markdown]
# ## Illustrations code blocks

# %% [markdown]
# ### Ditaa

# %%
+--------+   +-------+    /-------\
    |        | --+ ditaa +--> |       |
    |  Text  |   +-------+    |diagram|
    |Document|   |!magic!|    | cRED  |
    |     {d}|   | {io}  |    |       |
    +---+----+   +-------+    \-------/
        :                         ^
        |       Lots of work      |
        +-------------------------+

# %% [markdown]
# ## Ditaa

# %% [markdown]
# [DIagrams Through Ascii Art](http://ditaa.sourceforge.net/) :
