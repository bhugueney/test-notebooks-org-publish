// %% [markdown]
// ## Java code

// %%
System.out.println("Hello World !");

// %% [markdown]
// ## Java class

// %%
public class HelloWorld{
    public static void main(String[] args){
	System.out.println("Hello World !");
    }
}
